# %% [markdown]
# <a href="https://colab.research.google.com/github/carlinhoshk/Aulas-Curso-Python-Senai/blob/main/aula_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 13:00 - 02/02/2023
#
# Aula - 5

# %% [markdown]
# Expressões aritméticas
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EXERCICIOS ![image.png](data:image/png;base64,...)

# %%
# Exercicio A
formulaA = 80 + (12 / 10)
print("formula A ", formulaA)

# Exercicio B
formulaB = (2**4) / 11
print("formula B ", formulaB)

# Exercicio C
formulaC = 11 / (2**4)
print("formula C ", formulaC)

# Exercicio D 
formulaD = -(-80+(-10))
print("formula D ", formulaD)

# Exercicio E
formulaE = -(80/10)**2
print("formula E ", formulaE)

# Exercicio F
formulaF = (-(--10)/+(+-10))
print("formula F ", formulaF)

# Exercicio G
formulaG = -((400/2) -(- (400/10)))
print("formula G ", formulaG)

# Exercicio H
formulaH = (40%(10**1))
print("formula H ", formulaH)

# Exercicio I
formulaI = 40//(10**1)
print("formula I ", formulaI)

# Exercicio J 
formulaJ = (10000//(20%(10*10)))
print("formula J ", formulaJ)

# Exercicio K
formulaK = (-10000//(100 * (10**2)))
print("formula K ", formulaK)

# %% [markdown]
# 15:08
# - FLUXOGRAMAS
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nota_1 = float(input("Digite a nota 1: "))
nota_2 = float(input("Digite a nota 2: "))
nota_3 = float(input("Digite a nota 3: "))

# %%
media = (nota_1 + nota_2 + nota_3)/3
print("Sua média é: ", media)

# %%
if media >=7:
  print(f"Você foi aprovado com a média: {media}")
else:
  print(f"Você foi reprovado com a média: {media}")
