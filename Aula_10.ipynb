# %% [markdown]
# <a href="https://colab.research.google.com/github/carlinhoshk/Aulas-Curso-Python-Senai/blob/main/Aula_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Décima Aula.
#
# 13:33 - 28/02/2023

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# exemplo para ver se o remove exclui por nome de string

lista_compras = ['maça', 'batata', 'sabonete', 'picanha']
print(lista_compras)
lista_compras.remove('batata')

print(lista_compras)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# USAR O FOR QUANDO TEM FIM/FINITO .
#
#
# USAR O WHILE QUANDO NÃO-TEM-FIM/INFINITO .
#
#
# WHILE TRUE <- EXEMPLO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# LISTA DENTRO DE LISTA
#
# A MAÇA É LISTA COM SEU NOME, E PESO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# LEMBRAR DO ENUMERATE QUE ME FORNECE AUTOMATICAMENTE O INDICIE E O INTEM DA LISTA

# %%
n1 = 0.7
n2 = 0.1

print(n1+n2)
# Out:
# 0.7999999999999999

# %%
import decimal
# n1=0.7
# n2=0.1
# print(n1+n2)
numero_1 = decimal.Decimal('0.1')
numero_2 = decimal.Decimal('0.7')
numero_3 = numero_1 + numero_2
print(numero_3)
print(f'{numero_3:.2f}')
print(round(numero_3, 2))

# %% [markdown]
# SPLIT E JOIN
#
# ![image.png](data:image/png;base64,...)

# %%
frase = '   Olha só que   , coisa interessante          '
lista_frases_cruas = frase.split(',')
print(lista_frases_cruas)

# %%
frase = '   Olha só que   , coisa interessante          '
lista_frases_cruas = frase.split(',')

lista_frases = []
for i, frase in enumerate(lista_frases_cruas):
    lista_frases.append(lista_frases_cruas[i].strip())
    print(i, lista_frases)


# print(lista_frases_cruas)
# print(lista_frases)

frases_unidas = ', '.join(lista_frases)
print(frases_unidas)
# Out:
# 0 ['Olha só que']
# 1 ['Olha só que', 'coisa 1 interessante']
# Olha só que, coisa 1 interessante

# %%
salas = [
    # 0        1
    ['Maria', 'Helena', ],  # 0
    # 0
    ['Elaine', ],  # 1
    # 0       1       2
    ['Luiz', 'João', 'Eduarda', ],  # 2
]

# print(salas[1][0])
# print(salas[0][1])
# print(salas[2][2])
# print(salas[2][3][3])

for sala in salas:
    print(f'A sala é {salas}')
    for aluno in sala:
        print(aluno)

# %% [markdown]
# primeiro ler as salas e depois ele le cada sala os alunos dentro da lista

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import this  # <-- zen python

# %%
# Desempacotamento em chamadas
# de métodos e funções
string = 'ABCD'
lista = ['Maria', 'Helena', 1, 2, 3, 'Eduarda']
tupla = 'Python', 'é', 'legal'
salas = [
    # 0        1
    ['Maria', 'Helena', ],  # 0
    # 0
    ['Elaine', ],  # 1
    # 0       1       2
    ['Luiz', 'João', 'Eduarda', ],  # 2
]

p, b, *_, ap, u = lista
print(p, u, ap)

# print('Maria', 'Helena', 1, 2, 3, 'Eduarda')
print(*lista)
# print(*string)
# print(*tupla)

print(*salas)

# for teste in tupla:
#     print(teste)

# %% [markdown]
# usando o empacotador *_ para pegar o resto e atribuir a 'ap' e o ultimo 'u'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
condicao = 10 == 11
variavel = 'Valor' if condicao else 'Outro valor'
print(variavel)

# %% [markdown]
# achei facil porque não usa : pontos e cabe em 1 linha

# %%
digito = 9  # > 9 = 0
novo_digito = digito if digito <= 9 else 0
novo_digito = 0 if digito > 9 else digito
print(novo_digito)
# Out:
# 9

# %%
print('Valor' if False else 'Outro valor' if False else 'Fim')

# %% [markdown]
# EXERCICIO DA AULA 10
#
# Calculo do primeiro dígito do CPF
# CPF: 746.824.890-70
# Colete a soma dos 9 primeiros dígitos do CPF
# multiplicando cada um dos valores por uma
# contagem regressiva começando de 10
# Ex.:  746.824.890-70 (746824890)
#    10  9  8  7  6  5  4  3  2
# *  7   4  6  8  2  4  8  9  0
#    70  36 48 56 12 20 32 27 0
# Somar todos os resultados:
# 70+36+48+56+12+20+32+27+0 = 301
# Multiplicar o resultado anterior por 10
# 301 * 10 = 3010
# Obter o resto da divisão da conta anterior por 11
# 3010 % 11 = 7
# Se o resultado anterior for maior que 9:
#     resultado é 0
# contrário disso:
#     resultado é o valor da conta
# O primeiro dígito do CPF é 7
# """
# """
# split e join com list e str
# split - divide uma string (list)
# join - une uma string

# %%
# COMEÇO DO CODIGO EM AULA

# cpf = int(input("Digite os numeros do CPF"))
# i = 0 
# while i < len(cpf):
#     calculo =+ cpf[i]*(10-i)

while True:
    cpf = input("Digite os numeros do CPF ")
    i = 0 
    calculo = 0
    mult = 0
    
    while i < 9:
        mult += int(cpf[i]) * (10 - i)
        i += 1

    print(f"Os Digitos foram multiplicado e deu: {mult}")
    calculo = ((mult * 10) % 11)
    print(f"O calculo foi feito e o resto da divisão é: {calculo}")
    primeiro_digito = 0 if calculo > 9 else calculo
    print(f'O primeiro digito é: {primeiro_digito}')  

    sair = input("Deseja sair ? [s] ou [n]")
    if sair == 's':
      break
    else:
      continue    

# Minha resolução

# %% [markdown]
# USEI 2 WHILE para tentar fazer diferente do exemplo dado no exercicio

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Exercicio do 2 digito CPF

# %%
#CPF para o 2 digito 


while True:
    cpf = input("Digite os numeros do CPF ")
    i = 0 
    calculo = 0
    mult = 0
    flag = False
    
    while i < 9:
        mult += int(cpf[i]) * (10 - i)  # <- incremento com 10 digitos
        i += 1

    print(f"Os Digitos foram multiplicado e deu: {mult}")
    calculo = ((mult * 10) % 11)
    print(f"O calculo foi feito e o resto da divisão é: {calculo}")
    primeiro_digito = 0 if calculo > 9 else calculo
    print(f'O primeiro digito é: {primeiro_digito}')
    i = 0 
    calculo = 0
    mult = 0
    flag = True  
    

    sair = input("Deseja sair ? [s] ou [n]")
    if sair == 's':
      break
    else:
      
      cpf_2 = input("Digite seu CPF novamente ")

      while i < 10 and flag == True:
        mult += int(cpf_2[i]) * (11 - i)  # <- incremento com 11 digitos 
        i += 1

        calculo = ((mult * 10) % 11)
        segundo_digito = 0 if calculo > 9 else calculo
      print(f"O Segundo digito é: {segundo_digito}")
      i = 0 
      calculo = 0
      mult = 0
      flag = False 

# Minha resolução

# %%
# Resolução do professor em aula. 


cpf = input("Digite seu cpf ")
i=0
soma=0

while i < int(len(cpf)-1):
  mult =int(cpf[i])*(10-i)
  soma += mult
  i +=1

  
print(soma)

# %%
"""
Calculo do primeiro dígito do CPF
CPF: 746.824.890-70
Colete a soma dos 9 primeiros dígitos do CPF
multiplicando cada um dos valores por uma
contagem regressiva começando de 10
Ex.:  746.824.890-70 (746824890)
   10  9  8  7  6  5  4  3  2
*  7   4  6  8  2  4  8  9  0
   70  36 48 56 12 20 32 27 0
Somar todos os resultados: 
70+36+48+56+12+20+32+27+0 = 301
Multiplicar o resultado anterior por 10
301 * 10 = 3010
Obter o resto da divisão da conta anterior por 11
3010 % 11 = 7
Se o resultado anterior for maior que 9:
    resultado é 0
contrário disso:
    resultado é o valor da conta
O primeiro dígito do CPF é 7
"""
"""
split e join com list e str
split - divide uma string (list)
join - une uma string
"""

import os

while True:
    flag=None
    valor_cpf_cruo = input('Digite o CPF: ')
    valor_cpf = valor_cpf_cruo.split('.')
    cpf_unido = ''.join(valor_cpf).split('-')
    cpf_formatado=''.join(cpf_unido)
    mesma_seq = cpf_formatado[0]*len(cpf_formatado)

    if len(valor_cpf_cruo ) == 14 and flag == None and mesma_seq != cpf_formatado:
        soma_first=0
        i=0

        while i < 9:
            soma_first+= int(cpf_formatado[i])*(10-i)
            i+=1
        calculo_first = ((soma_first * 10) % 11)
        first_digito = 0 if calculo_first > 9 else calculo_first
        print(f'O valor do 1º Dígito é: {first_digito}')
        flag = True

    else:
        print('Por Favor. Digite o CPF corretamente! Usar . e -')
        continue

    if flag is True:
        soma_second=0
        i=0

        while i < 10:
            soma_second+= int(cpf_formatado[i])*(11-i)
            i+=1
        calculo_second = ((soma_second * 10) % 11)
        second_digito = 0 if calculo_second > 9 else calculo_second
        print(f'O valor do 2º Dígito é: {second_digito}')

    if cpf_formatado[9:11:1] == str(first_digito)+str(second_digito):
        print('CPF é Válido')

    else:
        print('CPF Inválido, Por Favor Digite Novamente.')
    sair = input('Digite [S] - para Sair ou [ ] - Qualquer Tecla para Continuar: ')

    if sair == 'S' or 's':
        os.system('cls')
        break  

    else:
        os.system('cls')
        continue
