# %% [markdown]
# <a href="https://colab.research.google.com/github/carlinhoshk/Aulas-Curso-Python-Senai/blob/main/Quinta_Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14:32 - 07/02/2023
#
# Exercício
# Peça ao usuário para digitar seu nome
# Peça ao usuário para digitar sua idade
# Se nome e idade forem digitados:
#     Exiba:
#
# > Bloco com recuo
#
#
#         Seu nome é {nome}
#         Seu nome invertido é {nome invertido}
#         Seu nome contém (ou não) espaços
#         Seu nome tem {n} letras
#         A primeira letra do seu nome é {letra}
#         A última letra do seu nome é {letra}
# Se nada for digitado em nome ou idade:
#     exiba "Desculpe, você deixou campos vazios."

# %%
nome = input("Digite seu nome: ")
idade = input("Digite sua idade: ")

conta_letras = len(nome)
espacos = ' '

if nome and idade:
    print(f"Seu nome é: {nome}")
    print(f"Seu nome invertido é: {nome[::-1]}")
    
    if espacos in nome:
        print("Seu nome tem espaços")
    else:
        print("Não contem espaços")
    print(f"Seu nome tem {conta_letras} letras")
    print(f"Primeira letra do seu nome é: {nome[0:1:]}")
    print(f"A ultima letra do seu nome é: {nome [conta_letras-1::]}")
else:
    print("Desculpe, você deixou campos vazios.")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
condicao = False
passou_no_if = None

if condicao:
    passou_no_if = True
    print('Faça algo')
else:
    print('Não faça algo')


if passou_no_if is None:
    print('Não passou no if')
else:
    print('Passou no if')

# %% [markdown]
# Exercicio 2
#
#
# ![image.png](data:image/png;base64,...)

# %%
numero = input("Digite um numero: ")

if numero.isdigit():
    if int(numero) % 2 == 0:
        print("Seu numero é par")
    else:
        print("Seu numero é impar")

else:
    print("Seu input não é um inteiro")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
horas = int(input("Digite a hora: "))

if (horas >=0 and horas <= 11):
    print("Bom dia!!")
if (horas >=12 and horas <= 17):
    print("Boa tarde!!")
if (horas >= 18 and horas <= 23):
    print("Boa noite !!")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nome = input("Digite seu nome: ")
conta_nome = len(nome)

if conta_nome <= 4:
    print("Seu nome é curto")
if conta_nome == 5 or conta_nome == 6:
    print("Seu nome é normal") 
if conta_nome > 6:
    print("seu nome é muito grande")
